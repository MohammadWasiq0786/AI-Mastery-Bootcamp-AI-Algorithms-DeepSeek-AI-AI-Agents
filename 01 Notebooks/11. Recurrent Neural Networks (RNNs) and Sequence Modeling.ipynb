# %% [markdown]
# # Course Name: **AI Mastery Bootcamp: AI Algorithms, DeepSeek AI, AI Agents**
#
# # Section 11: Week 11: **Recurrent Neural Networks (RNNs) and Sequence Modeling**

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, LSTM, GRU
from tensorflow.keras import Sequential
import matplotlib.pyplot as plt

# %%
# Load the dataset
vocab_size= 10000
max_len= 100
(X_train, y_train), (X_test, y_test)= imdb.load_data(num_words= vocab_size)

# Pad Sequences
X_train= pad_sequences(X_train, maxlen= max_len, padding= 'post')
X_test= pad_sequences(X_test, maxlen= max_len, padding= 'post')

print(f"Training Data Shape: {X_train.shape}, {y_train.shape}")
print(f"Testing Data Shape: {X_test.shape}, {y_test.shape}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training Data Shape: (25000, 100), (25000,)
# Testing Data Shape: (25000, 100), (25000,)

# %%
# Define the RNN model
rnn_model= Sequential([
    Embedding(input_dim=vocab_size, output_dim= 128),
    SimpleRNN(128, activation='tanh'),
    Dense(1, activation='sigmoid')
])

# Compile the model
rnn_model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# Print the model summary
rnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the LSTM model
lstm_model= Sequential([
    Embedding(input_dim=vocab_size, output_dim= 128),
    LSTM(128, activation='tanh'),
    Dense(1, activation='sigmoid')
])

# Compile the model
lstm_model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# Print the model summary
lstm_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define the GRU model
gru_model= Sequential([
    Embedding(input_dim=vocab_size, output_dim= 128),
    GRU(128, activation='tanh'),
    Dense(1, activation='sigmoid')
])

# Compile the model
gru_model.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])

# Print the model summary
gru_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train RNN Model
history_rnn= rnn_model.fit(X_train, y_train, validation_split= 0.2, epochs= 5, batch_size= 64, verbose= 1)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 32s 92ms/step - accuracy: 0.5464 - loss: 0.6802 - val_accuracy: 0.7230 - val_loss: 0.5346
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 39s 85ms/step - accuracy: 0.7504 - loss: 0.5122 - val_accuracy: 0.7838 - val_loss: 0.4817
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 40s 80ms/step - accuracy: 0.8242 - loss: 0.4185 - val_accuracy: 0.7670 - val_loss: 0.5025
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 81ms/step - accuracy: 0.8020 - loss: 0.4416 - val_accuracy: 0.6082 - val_loss: 0.6321
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 84ms/step - accuracy: 0.7451 - loss: 0.5113 - val_accuracy: 0.8070 - val_loss: 0.4680

# %%
# Train LSTM Model
history_lstm= lstm_model.fit(X_train, y_train, validation_split= 0.2, epochs= 5, batch_size= 64, verbose= 1)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 85s 263ms/step - accuracy: 0.6801 - loss: 0.5740 - val_accuracy: 0.8272 - val_loss: 0.3980
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 268ms/step - accuracy: 0.8732 - loss: 0.3173 - val_accuracy: 0.7920 - val_loss: 0.4444
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 144s 277ms/step - accuracy: 0.8877 - loss: 0.2753 - val_accuracy: 0.8478 - val_loss: 0.3640
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 146s 290ms/step - accuracy: 0.9388 - loss: 0.1779 - val_accuracy: 0.8390 - val_loss: 0.3986
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 87s 278ms/step - accuracy: 0.9609 - loss: 0.1160 - val_accuracy: 0.8320 - val_loss: 0.4813

# %%
# Train GRU Model
history_gru= gru_model.fit(X_train, y_train, validation_split= 0.2, epochs= 5, batch_size= 64, verbose= 1)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 98s 301ms/step - accuracy: 0.6469 - loss: 0.6000 - val_accuracy: 0.8230 - val_loss: 0.4160
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 91s 292ms/step - accuracy: 0.8842 - loss: 0.2904 - val_accuracy: 0.8350 - val_loss: 0.3713
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 141s 288ms/step - accuracy: 0.9319 - loss: 0.1826 - val_accuracy: 0.8442 - val_loss: 0.3605
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 146s 302ms/step - accuracy: 0.9663 - loss: 0.1089 - val_accuracy: 0.8494 - val_loss: 0.4231
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 138s 289ms/step - accuracy: 0.9801 - loss: 0.0618 - val_accuracy: 0.8282 - val_loss: 0.5301

# %%
# Evaluate the models
loss_rnn, accuracy_rnn= rnn_model.evaluate(X_test, y_test, verbose=0)
loss_lstm, accuracy_lstm= lstm_model.evaluate(X_test, y_test, verbose=0)
loss_gru, accuracy_gru= gru_model.evaluate(X_test, y_test, verbose=0)

print(f"RNN Test Accuracy: {accuracy_rnn:.4f}")
print(f"LSTM Test Accuracy: {accuracy_lstm:.4f}")
print(f"GRU Test Accuracy: {accuracy_gru:.4f}")
# Out:
# RNN Test Accuracy: 0.8065
# LSTM Test Accuracy: 0.8330
# GRU Test Accuracy: 0.8262

# %%
# Plot training accuracy
plt.plot(history_rnn.history['accuracy'], label= "RNN Training Accuracy")
plt.plot(history_lstm.history['accuracy'], label= "LSTM Training Accuracy")
plt.plot(history_gru.history['accuracy'], label= "GRU Training Accuracy")

plt.title("Training Accuracy Comparision")
plt.xlabel("Epoches")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
